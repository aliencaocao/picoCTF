# %%
# Cyberthon Data Science Training Materials
# Author: Ragul Balaji <ragulbalaji@ctf.sg>
# ALT-TAB LABS LLP (C) 2019-2022

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
d0 = cv2.imread('SentByAlice.png')
d1 = cv2.imread('RecvByBob.png')

# %%
d0.shape
# Out:
# (600, 800, 3)

# %%
plt.imshow(d0)

# %%
# fix color order
plt.imshow(cv2.cvtColor(d0, cv2.COLOR_BGR2RGB))

# %%
squarederror = np.sum((d0-d1)**2)
print(squarederror)
# Out:
# 3799890

# %%
difference = d0 - d1
plt.imshow(difference)

# %%
cv2.imwrite('diff.png', difference)
# Out:
# True
